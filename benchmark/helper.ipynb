# %%
import pandas as pd
from pandas_conversion_performance import plot_results

# %%
df = pd.read_csv('2023-10-07T00:09:04_91x91.csv')
fig = plot_results(df, show=False)
fig.savefig('2023-10-07T00:09:04_91x91.png')

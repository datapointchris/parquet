# %%
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import os
from pathlib import Path

# %%
apps = pd.read_csv('../data/application_record.csv')
apps
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
schema = pa.Schema.from_pandas(apps)
schema
# Out:
# ID: int64
# CODE_GENDER: string
# FLAG_OWN_CAR: string
# FLAG_OWN_REALTY: string
# CNT_CHILDREN: int64
# AMT_INCOME_TOTAL: double
# NAME_INCOME_TYPE: string
# NAME_EDUCATION_TYPE: string
# NAME_FAMILY_STATUS: string
# NAME_HOUSING_TYPE: string
# DAYS_BIRTH: int64
# DAYS_EMPLOYED: int64
# FLAG_MOBIL: int64
# FLAG_WORK_PHONE: int64
# FLAG_PHONE: int64
# FLAG_EMAIL: int64
# OCCUPATION_TYPE: string
# CNT_FAM_MEMBERS: double
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 2514

# %%
schema = schema.set(12, pa.field('FLAG_MOBIL', pa.bool_()))
schema = schema.set(13, pa.field('FLAG_WORK_PHONE', pa.bool_()))
schema = schema.set(14, pa.field('FLAG_PHONE', pa.bool_()))
schema = schema.set(15, pa.field('FLAG_EMAIL', pa.bool_()))
schema
# Out:
# ID: int64
# CODE_GENDER: string
# FLAG_OWN_CAR: string
# FLAG_OWN_REALTY: string
# CNT_CHILDREN: int64
# AMT_INCOME_TOTAL: double
# NAME_INCOME_TYPE: string
# NAME_EDUCATION_TYPE: string
# NAME_FAMILY_STATUS: string
# NAME_HOUSING_TYPE: string
# DAYS_BIRTH: int64
# DAYS_EMPLOYED: int64
# FLAG_MOBIL: bool
# FLAG_WORK_PHONE: bool
# FLAG_PHONE: bool
# FLAG_EMAIL: bool
# OCCUPATION_TYPE: string
# CNT_FAM_MEMBERS: double
# -- schema metadata --
# pandas: '{"index_columns": [{"kind": "range", "name": null, "start": 0, "' + 2514

# %%
apps.to_parquet('../data/apps.parquet', schema=schema)

# %%
apps.to_parquet('../data/partitioned', schema=schema, partition_cols=['NAME_INCOME_TYPE'])

# %%
pd.read_parquet('../data/partitioned', engine='pyarrow')
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008808           F            N               Y             0
# 1       5008809           F            N               Y             0
# 2       5008810           F            N               Y             0
# 3       5008811           F            N               Y             0
# 4       5008819           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6837905           M            Y               Y             1
# 438553  6837906           M            Y               Y             1
# 438554  6839936           M            Y               Y             1
# 438555  6840222           F            N               N             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               270000.0  Secondary / secondary special  Single / not married
# 1               270000.0  Secondary / secondary special  Single / not married
# 2               270000.0  Secondary / secondary special  Single / not married
# 3               270000.0  Secondary / secondary special  Single / not married
# 4               135000.0  Secondary / secondary special               Married
# ...                  ...                            ...                   ...
# 438552          355050.0  Secondary / secondary special               Married
# 438553          355050.0  Secondary / secondary special               Married
# 438554          135000.0  Secondary / secondary special               Married
# 438555          103500.0  Secondary / secondary special  Single / not married
# 438556          121500.0  Secondary / secondary special               Married
#
#         NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0       House / apartment      -19110          -3051        True
# 1       House / apartment      -19110          -3051        True
# 2       House / apartment      -19110          -3051        True
# 3       House / apartment      -19110          -3051        True
# 4       House / apartment      -17778          -1194        True
# ...                   ...         ...            ...         ...
# 438552  House / apartment      -15904          -2614        True
# 438553  House / apartment      -15904          -2614        True
# 438554  House / apartment      -12569          -2095        True
# 438555  House / apartment      -15939          -3007        True
# 438556  House / apartment      -18858          -1201        True
#
#         FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                 False        True        True     Sales staff
# 1                 False        True        True     Sales staff
# 2                 False        True        True     Sales staff
# 3                 False        True        True     Sales staff
# 4                 False       False       False        Laborers
# ...                 ...         ...         ...             ...
# 438552            False       False       False            None
# 438553            False       False       False            None
# 438554            False       False       False        Laborers
# 438555            False       False       False        Laborers
# 438556            False        True       False     Sales staff
#
#         CNT_FAM_MEMBERS      NAME_INCOME_TYPE
# 0                   1.0  Commercial associate
# 1                   1.0  Commercial associate
# 2                   1.0  Commercial associate
# 3                   1.0  Commercial associate
# 4                   2.0  Commercial associate
# ...                 ...                   ...
# 438552              3.0               Working
# 438553              3.0               Working
# 438554              3.0               Working
# 438555              1.0               Working
# 438556              2.0               Working
#
# [438557 rows x 18 columns]

# %%
filters = [('NAME_INCOME_TYPE', 'in', ['Working', 'State servant'])]
pd.read_parquet('../data/partitioned/', filters=filters)
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008868           F            N               Y             1
# 1       5008870           F            N               Y             1
# 2       5008981           M            Y               Y             0
# 3       5008983           M            Y               Y             0
# 4       5008984           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 262285  6837905           M            Y               Y             1
# 262286  6837906           M            Y               Y             1
# 262287  6839936           M            Y               Y             1
# 262288  6840222           F            N               N             0
# 262289  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL            NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0               211500.0  Secondary / secondary special        Civil marriage
# 1               211500.0  Secondary / secondary special        Civil marriage
# 2               112500.0  Secondary / secondary special               Married
# 3               112500.0  Secondary / secondary special               Married
# 4               112500.0  Secondary / secondary special               Married
# ...                  ...                            ...                   ...
# 262285          355050.0  Secondary / secondary special               Married
# 262286          355050.0  Secondary / secondary special               Married
# 262287          135000.0  Secondary / secondary special               Married
# 262288          103500.0  Secondary / secondary special  Single / not married
# 262289          121500.0  Secondary / secondary special               Married
#
#         NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  \
# 0       House / apartment      -16212          -7099        True
# 1       House / apartment      -16212          -7099        True
# 2       House / apartment      -20874          -2381        True
# 3       House / apartment      -20874          -2381        True
# 4       House / apartment      -20874          -2381        True
# ...                   ...         ...            ...         ...
# 262285  House / apartment      -15904          -2614        True
# 262286  House / apartment      -15904          -2614        True
# 262287  House / apartment      -12569          -2095        True
# 262288  House / apartment      -15939          -3007        True
# 262289  House / apartment      -18858          -1201        True
#
#         FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                 False       False       False      Core staff
# 1                 False       False       False      Core staff
# 2                 False        True       False         Drivers
# 3                 False        True       False         Drivers
# 4                 False        True       False         Drivers
# ...                 ...         ...         ...             ...
# 262285            False       False       False            None
# 262286            False       False       False            None
# 262287            False       False       False        Laborers
# 262288            False       False       False        Laborers
# 262289            False        True       False     Sales staff
#
#         CNT_FAM_MEMBERS NAME_INCOME_TYPE
# 0                   3.0    State servant
# 1                   3.0    State servant
# 2                   2.0    State servant
# 3                   2.0    State servant
# 4                   2.0    State servant
# ...                 ...              ...
# 262285              3.0          Working
# 262286              3.0          Working
# 262287              3.0          Working
# 262288              1.0          Working
# 262289              2.0          Working
#
# [262290 rows x 18 columns]

# %%
file = '../data/partitioned/NAME_INCOME_TYPE=Working/3f9a745063b9417a9a58752ffbfa4f73-0.parquet'
metadata = pq.read_metadata(file)
metadata
# Out:
# <pyarrow._parquet.FileMetaData object at 0x124a20180>
#   created_by: parquet-cpp-arrow version 13.0.0
#   num_columns: 17
#   num_rows: 226104
#   num_row_groups: 14
#   format_version: 2.6
#   serialized_size: 30812

# %%
parquet_file = pq.ParquetFile(file)
ts = parquet_file.metadata.row_group(0)

# %%
beautiful_df = pd.DataFrame()
for nm in range(ts.num_columns):
    path_in_schema = ts.column(nm).path_in_schema
    compressed_size = ts.column(nm).total_compressed_size
    stats = ts.column(nm).statistics
    min_value = stats.min
    max_value = stats.max
    physical_type = stats.physical_type
    beautiful_df[path_in_schema] = pd.DataFrame([physical_type, min_value, max_value, compressed_size])
df = beautiful_df.T
df.columns = ['DTYPE', 'Min', 'Max', 'Compressed_Size_(KO)']
df
# Out:
#                           DTYPE              Min  \
# ID                        INT64          5008804
# CODE_GENDER          BYTE_ARRAY                F
# FLAG_OWN_CAR         BYTE_ARRAY                N
# FLAG_OWN_REALTY      BYTE_ARRAY                N
# CNT_CHILDREN              INT64                0
# AMT_INCOME_TOTAL         DOUBLE          36000.0
# NAME_EDUCATION_TYPE  BYTE_ARRAY  Academic degree
# NAME_FAMILY_STATUS   BYTE_ARRAY   Civil marriage
# NAME_HOUSING_TYPE    BYTE_ARRAY  Co-op apartment
# DAYS_BIRTH                INT64           -24376
# DAYS_EMPLOYED             INT64           -15072
# FLAG_MOBIL              BOOLEAN             True
# FLAG_WORK_PHONE         BOOLEAN            False
# FLAG_PHONE              BOOLEAN            False
# FLAG_EMAIL              BOOLEAN            False
# OCCUPATION_TYPE      BYTE_ARRAY      Accountants
# CNT_FAM_MEMBERS          DOUBLE              1.0
#
#                                                Max Compressed_Size_(KO)
# ID                                         6820978                94394
# CODE_GENDER                                      M                 2252
# FLAG_OWN_CAR                                     Y                 2173
# FLAG_OWN_REALTY                                  Y                 1595
# CNT_CHILDREN                                    14                 3296
# AMT_INCOME_TOTAL                          900000.0                 9422
# NAME_EDUCATION_TYPE  Secondary / secondary special                 2806
# NAME_FAMILY_STATUS                           Widow                 3378
# NAME_HOUSING_TYPE                     With parents                 1698
# DAYS_BIRTH                                   -7980                25660
# DAYS_EMPLOYED                                  -17                22531
# FLAG_MOBIL                                    True                  145
# FLAG_WORK_PHONE                               True                 1563
# FLAG_PHONE                                    True                 1673
# FLAG_EMAIL                                    True                  890
# OCCUPATION_TYPE               Waiters/barmen staff                 7263
# CNT_FAM_MEMBERS                               15.0                 4124

# %%
from collections import defaultdict
partitions = defaultdict(list)
for root, dirs, files in os.walk('../data/partitioned/'):
    if len(dirs) > 0:
        for i, partition in enumerate(dirs):
            key, part = partition.split('=')
            partitions[key].append(part)
            print(i, partition)
            
dict(partitions)
# Out:
# 0 NAME_INCOME_TYPE=Student
# 1 NAME_INCOME_TYPE=Working
# 2 NAME_INCOME_TYPE=State%20servant
# 3 NAME_INCOME_TYPE=Commercial%20associate
# 4 NAME_INCOME_TYPE=Pensioner
# {'NAME_INCOME_TYPE': ['Student',
#   'Working',
#   'State%20servant',
#   'Commercial%20associate',
#   'Pensioner']}

# %%
def get_all_partitions(path):
    partitions = {}
    i = 0
    for (_, partitions_layer, _) in os.walk(path):
        if len(partitions_layer)>0:
            key = partitions_layer[0].split('=')[0]
            partitions[key] = sorted([partitions_layer[i].split('=')[1] for i in range(len(partitions_layer))])
        # else:
        #     break
    return partitions

get_all_partitions('../data/partitioned/')
# Out:
# {'NAME_INCOME_TYPE': ['Commercial%20associate',
#   'Pensioner',
#   'State%20servant',
#   'Student',
#   'Working']}

# %%
def get_parquet_schema(path):
    for p in Path(path).rglob('*'):
        if p.is_file() and p.suffix == '.parquet':
            return pq.read_schema(p)
path = '../data/partitioned/'
schema = get_parquet_schema(path)
schema
# Out:
# ID: int64
# CODE_GENDER: string
# FLAG_OWN_CAR: string
# FLAG_OWN_REALTY: string
# CNT_CHILDREN: int64
# AMT_INCOME_TOTAL: double
# NAME_EDUCATION_TYPE: string
# NAME_FAMILY_STATUS: string
# NAME_HOUSING_TYPE: string
# DAYS_BIRTH: int64
# DAYS_EMPLOYED: int64
# FLAG_MOBIL: bool
# FLAG_WORK_PHONE: bool
# FLAG_PHONE: bool
# FLAG_EMAIL: bool
# OCCUPATION_TYPE: string
# CNT_FAM_MEMBERS: double
# -- schema metadata --
# pandas: '{"index_columns": [], "column_indexes": [{"name": null, "field_n' + 2440
